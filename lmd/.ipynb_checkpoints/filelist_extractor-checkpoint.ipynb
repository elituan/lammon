# %%
from pathlib import Path
import pickle
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 from pathlib import Path
#       2 import pickle
# ----> 3 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
p = Path('./train')

# %%
filelist =['../data/CIFAR10' / x for x in p.glob('*/*')]
filelist
# Out:
# [PosixPath('../data/CIFAR10/train/airplane/0000.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0001.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0002.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0003.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0004.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0005.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0006.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0007.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0008.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0009.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0010.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0011.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0012.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0013.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0014.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0015.jpg'),
#  PosixPath('../data/CIFAR10/train/airplane/0016.jpg'),
# ...

# %%
print(type(filelist[0]))
# Out:
# <class 'pathlib.PosixPath'>

# %%
path = filelist[0]
path = Path(*path.parts[3:])
path = str(path)
path
# Out:
# 'train/airplane/0000.jpg'

# %%
import numpy as np
np.load(path,allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py:421, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     420 try:
# --> 421     return pickle.load(fid, **pickle_kwargs)
#     422 except Exception as e:
#
# UnpicklingError: invalid load key, '\xff'.
#
# The above exception was the direct cause of the following exception:
#
# UnpicklingError                           Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 np.load(path,allow_pickle=True)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py:423, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     421     return pickle.load(fid, **pickle_kwargs)
#     422 except Exception as e:
# --> 423     raise pickle.UnpicklingError(
# ...

# %%
with open(file

# %%
labels = [x.parts[-2] for x in filelist]
setLabel = list(set(labels))

# %%
class_mapping = {setLabel[i]:i for i in range(len(setLabel))}
class_mapping
# Out:
# {'airplane': 0,
#  'frog': 1,
#  'dog': 2,
#  'deer': 3,
#  'horse': 4,
#  'truck': 5,
#  'ship': 6,
#  'cat': 7,
#  'bird': 8,
#  'automobile': 9}

# %%
with open('label_dict.pkl','wb') as f:
    pickle.dump(class_mapping,f)

# %%
label_dict = class_mapping
label_dict
# Out:
# {'airplane': 0,
#  'frog': 1,
#  'dog': 2,
#  'deer': 3,
#  'horse': 4,
#  'truck': 5,
#  'ship': 6,
#  'cat': 7,
#  'bird': 8,
#  'automobile': 9}

# %%
label_dict[filelist[0].parts[-2]]
# Out:
# 0

# %%
import os.path as op
op.splitext(op.basename(filelist[0]))[0]
# Out:
# '0000'
